# %% [markdown]
# # Lorenz63 ETPF
#
# Minimal benchmark notebook for the ensemble transform particle filter.

# %% [markdown]
# ETPF uses an optimal-transport resampling map. This example requires the optional `POT` dependency and skips gracefully when it is unavailable.

# %%
# %run ../scripts/l63_etpf.py --cycles 5 --particles 20
