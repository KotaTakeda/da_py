# %%
import numpy as np
import matplotlib.pyplot as plt
from l96 import gen_l96, rk4
from loss import loss_rms
from visualize import plot_loss
from letkf import LETKF

# %%
# Lorenz96の設定
J = 40
F = 8
lorenz = gen_l96(F)

# 同化step
# 時間発展は0.01ごとに行う
dt = 0.05

# モデルの遷移関数(非線形)
# 0.01ずつ時間発展させる
# dtは同化step
def M(x, dt):
    for i in range(int(dt/0.01)):
        x = rk4(lorenz, 0, x, 0.01)
    return x

# 単位行列
I = np.eye(J)

# 観測
H = I

# モデル誤差共分散, 最初は完全モデルを仮定
Q = np.zeros((J, J))

# 観測誤差共分散, 後で定数倍の変化をさせる.
r = 1.0
R = r*I

# 観測値と真値
end_step = -1 # 開発用
x_true = np.load('../data/x_true.npy')[:end_step]
y = np.load('../data/x_obs.npy')[:end_step]
if not np.isclose(r, 1.0):
    y = x_true + np.random.normal(loc=0, scale=r, size=x_true.shape) # R = r*I

# KFの初期値
seed = 1
np.random.seed(seed)
x_0 = x_true[np.random.randint(len(x_true)-1)]

P_0 = 25*I

# %%
letkf = LETKF(M, H, R, x_0, P_0, m=8, alpha=1.03, seed=seed,
            c=6.0, localization='gaspari-cohn', addaptive=False, multi_process=False)
for y_obs in y:
    letkf.forecast(dt)
    letkf.update(y_obs)

x_assim = letkf.x
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 5
#       3 for y_obs in y:
#       4     letkf.forecast(dt)
# ----> 5     letkf.update(y_obs)
#       7 x_assim = letkf.x
#
# File ~/Locals/code/github/data_assimilation_py/code/letkf.py:126, in LETKF.update(self, y_obs)
#     124 else:
#     125     for i in range(self.dim_x):
# --> 126         self.X[:, i] = self._transform_each(i, dy, dY, dX_f)
#     128 # 記録: 更新した値のアンサンブル平均xを保存, 推定誤差共分散P_fのtraceを保存
#     129 self.x.append(self.X.mean(axis=0))
#
# File ~/Locals/code/github/data_assimilation_py/code/letkf.py:139, in LETKF._transform_each(self, i, dy, dY, dX_f)
#     134 C = dY @ self._locR(i)  # localization: invRの各i行にrho_iをかける．(m, dim_y)
#     135 P_at = inv(
#     136     ((self.m - 1) / self.alpha) * self.I + C @ dY.T
#     137 )  # アンサンブル空間でのP_a．(m, m)
#     138 T = (
# --> 139     P_at @ C @ dy + sqrtm((self.m - 1) * P_at)
#     140 ).T  # 注:Pythonの使用上第１項(mean update)が行ベクトルとして足されているので転置しておく．(m, m)
#     141 return self.x_mean[i] + (dX_f.T @ T).T[:, i]
#
# KeyboardInterrupt:

# %%
fig, ax = plt.subplots(figsize=(10, 2))
plot_loss(x_true, y, loss_rms, ax=ax, label='obs', lw=0.3)
plot_loss(x_true, x_assim, loss_rms, ax=ax, label='letkf', lw=0.3)
ax.legend()
ax.set_ylim([0, 2])
# Out:
# half-tail loss mean: 1.1451
# half-tail loss mean: 0.1970
# (0.0, 2.0)

# %% [markdown]
# # optimize letkf

# %%
import pandas as pd
import seaborn as sns
from tqdm import tqdm
from optimize import gen_assim_func, grid_search2, gen_eval_func

# %%
spin_up = 200

def compute_rmse(x):
    return loss_rms(x_true[spin_up:], x[spin_up:]).mean()

# %% [markdown]
# ## alpha-c

# %%
fixed_params = {
    "M": M,
    "H": H,
    "R": R, 
    "x_0": x_0,
    "P_0": P_0,
    "m": 8,
    "seed":seed,
    "localization": 'gaspari-cohn',
    "addaptive": False,
    "multi_process": False,
}

num_alpha = 2
num_c = 3
params_alpha = np.linspace(1.03-0.02, 1.03+0.02, num=num_alpha)
params_c = np.arange(num_c)*(2/5) + 10.0
n_process = 6
# try:
#     df = pd.read_csv('../data/letkf_alpha_c_detail.csv', index_col=0, header=0)
# except:
# evaluate = gen_eval_func(LETKF, fixed_params, y, dt, compute_rmse)
def evaluate(params):
    instance = LETKF(**{**fixed_params, **params})
    print(params)
    for y_obs in tqdm(y):
        instance.forecast(dt)
        instance.update(y_obs)
    return compute_rmse(instance.x)

df = grid_search2(evaluate, "alpha", params_alpha, "c", params_c, n_process)
df.to_csv('../data/letkf_alpha_c_detail.csv')

plt.figure(figsize=(8, 8))
sns.heatmap(df, annot=True, fmt=".4f")
# Out:
# 6
# {'alpha': 1.01, 'c': 10.0}{'alpha': 1.01, 'c': 10.8}{'alpha': 1.01, 'c': 10.4}{'alpha': 1.05, 'c': 10.0}{'alpha': 1.05, 'c': 10.4}{'alpha': 1.05, 'c': 10.8}
#   0%|          | 0/1439 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 14
#      11         instance.update(y_obs)
#      12     return compute_rmse(instance.x)
# ---> 14 df = grid_search(evaluate, "alpha", params_alpha, "c", params_c, n_process)
#      15 # df = grid_search(evaluate, "alpha", params_alpha, "c", params_c)
#      16 df.to_csv('../data/letkf_alpha_c_detail.csv')
#
# File ~/Documents/code/data_assimilation_py/code/optimize.py:53, in grid_search(evaluate, param1_name, params1, param2_name, params2, n_process)
#      51 print(len(params_kv))
#      52 # n_process = 4
# ---> 53 errors = exec_mp(evaluate, params_kv, n_process)
#      54 df = pd.DataFrame(
#      55     errors.reshape(len(params1), len(params2)), index=params1, columns=params2
#      56 )
#      57 return df
#
# File ~/Documents/code/data_assimilation_py/code/optimize.py:62, in exec_mp(func, params, n_process)
#      60 def exec_mp(func, params, n_process):
#      61     with get_context("fork").Pool(n_process) as pl:
# ---> 62         results = np.array(pl.map(func, params)).T
#      63         pl.close()
#      64         pl.join()
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/multiprocessing/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/multiprocessing/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %% [markdown]
# # m-c

# %%
# TODO: multiprocess対応
fixed_params = {
    "M": M,
    "H": H,
    "R": R, 
    "x_0": x_0,
    "P_0": P_0,
    "alpha": 1.03,
    "seed":seed,
    "localization": 'gaspari-cohn',
    "addaptive": False,
    "multi_process": False,
}

params_m = [8, 12, 16, 20]
params_c = [5., 6., 7., 8., 9., 10.]
n_multi = 4
multi_type="process"
target_filename = 'letkf_m_c'
print(target_filename)

try:
    df = pd.read_csv(f'../data/{target_filename}.csv', index_col=0, header=0)
except:
    def evaluate(params):
        instance = LETKF(**{**fixed_params, **params})
        for y_obs in tqdm(y):
            instance.forecast(dt)
            instance.update(y_obs)
        return compute_rmse(instance.x)
    df = grid_search2(evaluate, "m", params_m, "c", params_c, n_multi, multi_type)
    df.to_csv(f'../data/{target_filename}.csv')

plt.figure(figsize=(8, 8))
sns.heatmap(df, annot=True, fmt=".4f")
# Out:
# letkf_m_c
#   3%|▎         | 40/1439 [00:02<01:16, 18.21it/s]/Users/sakajolabtakeda/Locals/code/github/data_assimilation_py/code/letkf.py:126: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.X[:, i] = self._transform_each(i, dy, dY, dX_f)
# 100%|██████████| 1439/1439 [01:09<00:00, 20.68it/s]
# 100%|██████████| 1439/1439 [01:09<00:00, 20.64it/s]
# 100%|██████████| 1439/1439 [01:09<00:00, 20.59it/s]
# 100%|██████████| 1439/1439 [01:28<00:00, 16.28it/s]
# 100%|██████████| 1439/1439 [01:06<00:00, 21.65it/s]
#  99%|█████████▉| 1430/1439 [01:06<00:00, 21.40it/s]
# 100%|██████████| 1439/1439 [01:06<00:00, 21.58it/s]
#   1%|          | 13/1439 [00:00<01:38, 14.53it/s]]/Users/sakajolabtakeda/Locals/code/github/data_assimilation_py/code/letkf.py:126: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.X[:, i] = self._transform_each(i, dy, dY, dX_f)
# 100%|██████████| 1439/1439 [01:25<00:00, 16.89it/s]
# 100%|██████████| 1439/1439 [01:23<00:00, 17.22it/s]
# 100%|██████████| 1439/1439 [01:23<00:00, 17.18it/s]
# 100%|██████████| 1439/1439 [01:41<00:00, 14.20it/s]
# 100%|██████████| 1439/1439 [01:40<00:00, 14.35it/s]
# 100%|██████████| 1439/1439 [01:23<00:00, 17.31it/s]
#  29%|██▉       | 419/1439 [00:29<01:12, 14.11it/s]]
#   0%|          | 7/1439 [00:00<01:45, 13.62it/s]/Users/sakajolabtakeda/Locals/code/github/data_assimilation_py/code/letkf.py:126: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.X[:, i] = self._transform_each(i, dy, dY, dX_f)
# 100%|██████████| 1439/1439 [01:42<00:00, 14.08it/s]
# 100%|██████████| 1439/1439 [01:43<00:00, 13.96it/s]
# 100%|██████████| 1439/1439 [01:43<00:00, 13.96it/s]
# 100%|██████████| 1439/1439 [02:07<00:00, 11.33it/s]
# 100%|██████████| 1439/1439 [02:09<00:00, 11.14it/s]
# 100%|██████████| 1439/1439 [02:07<00:00, 11.28it/s]
# 100%|██████████| 1439/1439 [01:43<00:00, 13.89it/s]
# 100%|██████████| 1439/1439 [02:04<00:00, 11.60it/s]
# 100%|██████████| 1439/1439 [01:57<00:00, 12.25it/s]
# 100%|██████████| 1439/1439 [01:42<00:00, 14.07it/s]
# <Axes: >
